# %%
import csv 
import json 
import pandas as pd

# %%
df = pd.read_csv ('Covid_Data.csv')
# df.to_json ('OxCGRT_US_latest.json')

# %%
df.to_json('Covid_Data.json')

# %%
with open('Covid_Data.json') as f:
   data = json.load(f)

print(data)
# Out:
# {'CountryName': {'0': 'United States', '1': 'United States', '2': 'United States', '3': 'United States', '4': 'United States', '5': 'United States', '6': 'United States', '7': 'United States', '8': 'United States', '9': 'United States', '10': 'United States', '11': 'United States', '12': 'United States', '13': 'United States', '14': 'United States', '15': 'United States', '16': 'United States', '17': 'United States', '18': 'United States', '19': 'United States', '20': 'United States', '21': 'United States', '22': 'United States', '23': 'United States', '24': 'United States', '25': 'United States', '26': 'United States', '27': 'United States', '28': 'United States', '29': 'United States', '30': 'United States', '31': 'United States', '32': 'United States', '33': 'United States', '34': 'United States', '35': 'United States', '36': 'United States', '37': 'United States', '38': 'United States', '39': 'United States', '40': 'United States', '41': 'United States', '42': 'United States', '4
# ...
